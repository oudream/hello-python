# %%
import sys


print()
print('----')
print(sys.path)

print('----')

for k, v in sys.modufffff







faa
print(sys.modules)
# Out:
# ['', '/ddd/cpy/cpy', '/ddd/cpy/cpy/cpy/hello', '/Library/Frameworks/Python.framework/Versions/3.6/lib/python36.zip', '/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6', '/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/lib-dynload', '/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages', '/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/extensions', '/Users/oudream/.ipython']
# ----
# ...
